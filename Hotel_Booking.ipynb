# %% [markdown]
# <a href="https://colab.research.google.com/github/Kyash24/Hotel_Bookings_Project/blob/main/Hotel_Booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Importing All The Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading The Dataset**

# %%
df=pd.read_csv('/content/hotel_booking.csv')

# %% [markdown]
# ## **Exploratory Data Analysis and Data Cleaning**

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel          0.0      342.0             2015.0               July
# 1  Resort Hotel          0.0      737.0             2015.0               July
# 2  Resort Hotel          0.0        7.0             2015.0               July
# 3  Resort Hotel          0.0       13.0             2015.0               July
# 4  Resort Hotel          0.0       14.0             2015.0               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                      27.0                        1.0
# 1                      27.0                        1.0
# 2                      27.0                        1.0
# 3                      27.0                        1.0
# 4                      27.0                        1.0
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                      0.0                   0.0     2.0  ...      Transient
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 5034  Resort Hotel          1.0       35.0             2016.0
# 5035  Resort Hotel          1.0       26.0             2016.0
# 5036  Resort Hotel          1.0       27.0             2016.0
# 5037  Resort Hotel          1.0       30.0             2016.0
# 5038  Resort Hotel          NaN        NaN                NaN
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 5034              April                      16.0                       13.0
# 5035              April                      16.0                       13.0
# 5036              April                      16.0                       14.0
# 5037              April                      16.0                       14.0
# 5038                NaN                       NaN                        NaN
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df.shape
# Out:
# (5039, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5039 entries, 0 to 5038
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           5039 non-null   object
#  1   is_canceled                     5038 non-null   float64
#  2   lead_time                       5038 non-null   float64
#  3   arrival_date_year               5038 non-null   float64
#  4   arrival_date_month              5038 non-null   object
#  5   arrival_date_week_number        5038 non-null   float64
#  6   arrival_date_day_of_month       5038 non-null   float64
#  7   stays_in_weekend_nights         5038 non-null   float64
#  8   stays_in_week_nights            5038 non-null   float64
#  9   adults                          5038 non-null   float64
#  10  children                        5038 non-null   float64
#  11  babies                          5038 non-null   float64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5039 entries, 0 to 5038
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           5039 non-null   object
#  1   is_canceled                     5038 non-null   float64
#  2   lead_time                       5038 non-null   float64
#  3   arrival_date_year               5038 non-null   float64
#  4   arrival_date_month              5038 non-null   object
#  5   arrival_date_week_number        5038 non-null   float64
#  6   arrival_date_day_of_month       5038 non-null   float64
#  7   stays_in_weekend_nights         5038 non-null   float64
#  8   stays_in_week_nights            5038 non-null   float64
#  9   adults                          5038 non-null   float64
#  10  children                        5038 non-null   float64
#  11  babies                          5038 non-null   float64
# ...

# %%
df.describe(include='object')
# Out:
#                hotel arrival_date_month  meal country market_segment  \
# count           5039               5038  5038    5036           5038
# unique             1                 10     5      57              6
# top     Resort Hotel               July    BB     PRT      Online TA
# freq            5039                842  3425    3208           2163
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                  5038               5038               5038
# unique                    3                  9                 10
# top                   TA/TO                  A                  A
# freq                   3689               3197               2567
#
#        deposit_type customer_type reservation_status             name  \
# count          5038          5038               5038             5038
# unique            3             4                  3             4873
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in df.describe(include='object').columns:
  print(col)
  print(df[col].unique())
  print('-'*50)
# Out:
# hotel
# ['Resort Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' nan]
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined' nan]
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE']
# --------------------------------------------------
# market_segment
# ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  nan]
# --------------------------------------------------
# distribution_channel
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df.drop(['company','agent'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  19781.000000  19781.000000       19781.000000
# mean       0.558010    110.740407        2015.807492
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     24.000000        2015.000000
# 50%        1.000000     82.000000        2016.000000
# 75%        1.000000    178.000000        2016.000000
# max        1.000000    737.000000        2017.000000
# std        0.496636    101.703763           0.773974
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              19781.000000               19781.000000
# mean                  30.244224                  15.700369
# min                    1.000000                   1.000000
# 25%                   20.000000                   8.000000
# 50%                   32.000000                  16.000000
# 75%                   41.000000                  24.000000
# max                   53.000000                  31.000000
# ...

# %%
df=df[df['adr']<5000]

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  19781.000000  19781.000000       19781.000000
# mean       0.558010    110.740407        2015.807492
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     24.000000        2015.000000
# 50%        1.000000     82.000000        2016.000000
# 75%        1.000000    178.000000        2016.000000
# max        1.000000    737.000000        2017.000000
# std        0.496636    101.703763           0.773974
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              19781.000000               19781.000000
# mean                  30.244224                  15.700369
# min                    1.000000                   1.000000
# 25%                   20.000000                   8.000000
# 50%                   32.000000                  16.000000
# 75%                   41.000000                  24.000000
# max                   53.000000                  31.000000
# ...

# %% [markdown]
# ## **Data Analysis and Visualization**

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)

plt.figure(figsize=(5,4))
plt.pie(cancelled_perc.values,labels=cancelled_perc.index,autopct='%1.1f%%',startangle=90)
plt.title('Booking Cancellation Percentage')
plt.show()
# Out:
# is_canceled
# 0.0    0.536919
# 1.0    0.463081
# Name: proportion, dtype: float64

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)

plt.figure(figsize=(5,4))
plt.title('Reservation status count')

plt.bar(['Not canceled','Canceled'],df['is_canceled'].value_counts(), edgecolor = 'k',width =0.7)
plt.show()
# Out:
# is_canceled
# 0.0    0.536919
# 1.0    0.463081
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,4))
ax1=sns.countplot(x='hotel',hue='is_canceled',data=df,palette='Blues')
legend_labels,_=ax1.get_legend_handles_labels()
plt.title('Reservation Status in different Hotels',size=20)
plt.xlabel('Hotel')
plt.ylabel('number of reservation')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
resort_hotel=df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0.0    0.536919
# 1.0    0.463081
# Name: proportion, dtype: float64

# %%
city_hotel=df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# Series([], Name: proportion, dtype: float64)

# %%
resort_hotel= resort_hotel.groupby('reservation_status_date')['adr'].mean()
city_hotel= city_hotel.groupby('reservation_status_date')['adr'].mean()

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in City and Resort Hotel',fontsize=30)
plt.plot(resort_hotel.index, resort_hotel, label='Resort Hotel') # Removed ['adr'] as it is not a column anymore
plt.plot(city_hotel.index,city_hotel,label='City Hotel') # Removed ['adr'] as it is not a column anymore
plt.legend(fontsize=20)
plt.show()

# %%
df['month']=df['reservation_status_date'].dt.month_name()
plt.figure(figsize=(16,8))
ax1=sns.countplot(x= 'month',hue='is_canceled',data =df,palette='bright')
legend_labels,_=ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation Status per Month',size=20)
plt.xlabel('Month')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per Month',fontsize=30)
# Removed the extra data argument that was causing the error.
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.legend(fontsize = 20)
plt.show()

# %%
cancelled_data = df[df['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title('Top 10 Countries with Most Reservation Cancellations')
plt.pie(top_10_country,autopct='%.2f',labels= top_10_country.index)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        8974
# Groups           3770
# Offline TA/TO    3342
# Direct           2421
# Corporate        1193
# Complementary      81
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.453668
# Groups           0.190587
# Offline TA/TO    0.168950
# Direct           0.122390
# Corporate        0.060310
# Complementary    0.004095
# Name: proportion, dtype: float64

# %%
 cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.565320
# Groups           0.224044
# Offline TA/TO    0.101286
# Direct           0.077097
# Corporate        0.029263
# Complementary    0.002990
# Name: proportion, dtype: float64

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date',inplace= True)

not_cancelled_df = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_df.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date',inplace= True)

plt.figure(figsize=(20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='Not canceled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='Canceled')
plt.legend()

# %%
cancelled_df_adr= cancelled_df_adr[(cancelled_df_adr['reservation_status_date'] > '2016') & (cancelled_df_adr['reservation_status_date'] < '2017-09')]
not_cancelled_df_adr= not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date'] > '2016') & (not_cancelled_df_adr['reservation_status_date'] < '2017-09')]

# %%
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate', fontsize =30)
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='Not canceled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='Canceled')
plt.legend(fontsize = 20)
plt.show()
